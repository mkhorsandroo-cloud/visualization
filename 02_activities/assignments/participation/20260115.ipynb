# %% [markdown]
# For the first image in activity which is : life expectancy 2007
#
# Is it pleasing to look at?
# Yes, the colors and 3D style are visually appealing and eye-catching.
#
# Does it accurately represent the data?
# Not really. The 3D perspective distorts bar lengths and makes comparisons harder.
#
# Is the message clear?
# The general idea (life expectancy by continent) is understandable, but exact differences are unclear.
#
# Is this a “good” visualization? Why or why not?
# No. While it looks attractive, the use of 3D effects and perspective hurts accuracy and readability, so it’s misleading for comparison.

# %% [markdown]
# For the second image in activity which is : Monstrous costs
#
# Is it pleasing to look at?
# Yes, it is visually striking and memorable because of the illustration.
#
# Does it accurately represent the data?
# Not very well. The exaggerated shapes and angles make it hard to judge actual values.
#
# Is the message clear?
# Yes. It clearly tries to show that campaign costs are increasing dramatically over time.
#
# Is this a “good” visualization? Why or why not?
# Mostly no. It communicates a strong message, but prioritizes visual impact over clarity and precise data interpretation.

# %% [markdown]
# For the third image in activity which is : The same data presented with two different aspect ratio
#
# Is it pleasing to look at?
# Yes, both plots are clean and simple, but the wider one is easier on the eyes.
#
# Does it accurately represent the data?
# Yes, both show the same data correctly, but they feel different because of the aspect ratio.
#
# Is the message clear?
# Yes. It shows growth over x, but the left plot makes the growth look much steeper.
#
# Is this a “good” visualization? Why or why not?
# The right one is better. Aspect ratio matters—poor scaling can exaggerate trends and mislead the viewer.

# %% [markdown]
# For the fourth image in activity which is : 2012 Presidential RUN
#
# Is it pleasing to look at?
# It is visually flashy, but quite cluttered and distracting.
#
# Does it accurately represent the data?
# No. The percentages add up to more than 100%, which makes the pie chart incorrect.
#
# Is the message clear?
# Somewhat. It tries to show support for different candidates, but the data presentation is confusing.
#
# Is this a “good” visualization? Why or why not?
# No. A pie chart is inappropriate here, and the incorrect percentages make it misleading and unreliable.

# %% [markdown]
# For the fifth image in activity which is : Wind Map
#
# Is it pleasing to look at?
# Yes, it is visually elegant and engaging, with smooth flow lines.
#
# Does it accurately represent the data?
# Yes. Wind direction and relative speed are clearly encoded through motion and density.
#
# Is the message clear?
# Yes. It effectively shows wind patterns and movement across the map.
#
# Is this a “good” visualization? Why or why not?
# Yes. It balances aesthetics and accuracy well and is especially effective as an interactive visualization for exploring patterns.
